# %% [markdown]
# # Car price prediction with Nigeria dataset (Jiji) Usin Machine Learning Algorithms.

# %% [markdown]
# ## 1. Data Collection

# %% [markdown]
# #### The dataset used in this project was obtained from a popular online marketplace Jiji (https://jiji.ng/cars).
# Jiji is a website in Africa that connects consumers and sellers so they can exchange goods and services.
# The website was scraped beautifulsoup, and saves as `new_scrape.csv` in CSV format.

# %% [markdown]
# ## 2. Data Preprocessing
# **Performing data cleaning**

# %%
# required libraries and pakages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv("../dataset/new_scrape.csv")

# %%
# take a look of the data
print("Shape: ", df.shape)
df.head()
# Out:
# Shape:  (5122, 30)
#                                  Name         Price        Market price  \
# 0            Toyota Tacoma 2014 White   ₦ 8,800,000  ₦ 13.48 M ~ 14.5 M
# 1              Lexus GX 460 2010 Gray  ₦ 19,500,000   ₦ 17.5 M ~ 18.5 M
# 2                  Acura MDX 2011 Red  ₦ 7,500,000,     ₦ 6.5 M ~ 7.1 M
# 3  Hyundai Elantra Limited 2012 Black   ₦ 4,800,000    ₦ 4.8 M ~ 5.24 M
# 4         Lexus RX 350 AWD 2013 White  ₦ 13,500,000   ₦ 13.5 M ~ 13.9 M
#
#          Location                                          Thumbnail  \
# 0     Lagos, Ajah  https://pictures-nigeria.jijistatic.com/112155...
# 1   Lagos, Magodo  https://pictures-nigeria.jijistatic.com/113346...
# 2    Lagos, Apapa  https://pictures-nigeria.jijistatic.com/107470...
# 3      Lagos, Ojo  https://pictures-nigeria.jijistatic.com/912612...
# 4  Lagos, Gbagada  https://pictures-nigeria.jijistatic.com/111479...
#
#                                               Images       Gear  Odometer  \
# 0  https://pictures-nigeria.jijistatic.com/112155...  Automatic       NaN
# 1  https://pictures-nigeria.jijistatic.com/113346...  Automatic       NaN
# 2  https://pictures-nigeria.jijistatic.com/107470...  Automatic  75000 km
# 3  https://pictures-nigeria.jijistatic.com/912612...  Automatic       NaN
# 4  https://pictures-nigeria.jijistatic.com/111479...  Automatic  70431 km
#
#   Fuel type Car condition  ...        Engine Size Number of Cylinders  \
# 0    Petrol  Foreign Used  ...  2700           cc                 4.0
# 1    Petrol  Foreign Used  ...  4600           cc                 8.0
# 2    Petrol  Foreign Used  ...  3700           cc                 6.0
# 3    Petrol  Foreign Used  ...  1800           cc                 4.0
# 4    Petrol  Foreign Used  ...  3500           cc                 6.0
#
#         Horse Power  Color Seats Registered Car  Exchange Possible  \
# 0  159           hp  White   NaN            NaN                NaN
# 1  305           hp   Gray     7            NaN                NaN
# 2  300           hp    Red     7             No                NaN
# 3  150           hp  Black     5             No                NaN
# 4  270           hp  White     5            NaN                NaN
#
#   VIN Chassis number Mileage VIN number
# 0                NaN     NaN        NaN
# 1                NaN     NaN        NaN
# 2                NaN     NaN        NaN
# 3                NaN     NaN        NaN
# 4                NaN     NaN        NaN
#
# [5 rows x 30 columns]

# %%
# rename column name to snake case
df.columns = [column.lower().replace(" ", "_") for column in df.columns]

# %%
# check the percentage of null values
# 100 * df.isnull().sum() / len(df)

# %%
# let calculate and show the percentage of the missing data
def null_value_percentage(df):
    percent_missing = 100 * df.isnull().sum() / len(df)
    percent_missing = percent_missing[percent_missing > 0].sort_values()
    return percent_missing

# %%
null_value_percentage = null_value_percentage(df)

# %%
### The last three features has the highest percentage of missing data
print(null_value_percentage)
# Out:
# location                0.488091
# gear                    0.488091
# color                   0.488091
# car_condition           0.488091
# year_of_manufacture     0.488091
# make                    0.488091
# model                   0.488091
# second_condition        0.546661
# market_price           15.599375
# registered_car         18.156970
# trim                   36.157751
# number_of_cylinders    40.003905
# body                   40.960562
# drivetrain             42.737212
# fuel_type              42.737212
# seats                  43.010543
# engine_size            43.459586
# horse_power            46.075752
# odometer               51.210465
# other_features         69.875049
# exchange_possible      73.975010
# vin_chassis_number     96.583366
# vin_number             99.902382
# mileage                99.921906
# dtype: float64

# %%
# bar chart to show the percentage of missing data
plt.figure(figsize=(6, 2))
sns.barplot(x=null_value_percentage.index, y=null_value_percentage)
plt.xticks(rotation=90);

# %%
# plt.figure(figsize=(6, 2))
# sns.barplot(x=null_value_percentage.index, y=null_value_percentage)
# plt.xticks(rotation=90);
# plt.ylim((0,1))

# %%
# 100 / len(df)

# %% [markdown]
# ### Since, all the media data and the links are not applicable here, we remove them
# *There is no need for the car images, thumbnail and page link. So, let's drop them.*

# %%
df = df.drop(["thumbnail", "images", "page_link"], axis=1)

# %% [markdown]
# ### Cleaning the *price* column to extract the price digit.

# %%
# extract digit out from the price column
def clean_price(price):
    new_price = ''.join(price.split()[1].split(','))
    return float(new_price)

# %%
# plt.figure(figsize=(8, 4))
df["actual_price"] = df["price"].apply(clean_price)

# %%
df.columns
# Out:
# Index(['name', 'price', 'market_price', 'location', 'gear', 'odometer',
#        'fuel_type', 'car_condition', 'other_features', 'dealer_name',
#        'second_condition', 'make', 'model', 'year_of_manufacture', 'trim',
#        'body', 'drivetrain', 'engine_size', 'number_of_cylinders',
#        'horse_power', 'color', 'seats', 'registered_car', 'exchange_possible',
#        'vin_chassis_number', 'mileage', 'vin_number', 'actual_price'],
#       dtype='object')

# %% [markdown]
# ### Check the location that has the highest car

# %%
location_count = df.groupby('location')['price'].count().sort_values()

# %%
# bar plot
plt.figure(figsize=(10, 2), dpi=100)
sns.barplot(x=location_count.index, y=location_count)
plt.xticks(rotation=90);

# %%
# def get_market_price_range(market_price: str) -> tuple:
#     # print("Market Price: ", market_price, type(market_price))

#     if isinstance(market_price, str):
        
#         if "₦" in market_price:
#             market_price = market_price.replace("₦", "").split("~")
            
#         # print(market_price)
            
#         for index, price in enumerate(market_price):
#             price = price.strip()
#             if "K" in price:
#                 price = price.replace("K", "").strip()
#                 market_price[index] = float(price) * 1000
#             elif "M" in price:
#                 price = price.replace("M", "").strip()
#                 market_price[index] = float(price) * 1000000
                
                
#         return market_price

#     return market_price

# %%
'₦ 13.48 M ~ 14.5 M'.split("~")[1].strip()[:-1].strip()
# Out:
# '14.5'

# %%
def get_market_price_range(market_prices):
    
    lower_market_price = []
    higher_market_price = []
    
    for price in market_prices:
        
        if not isinstance(price, str):
            lower_market_price.append(np.nan)
            higher_market_price.append(np.nan)
            continue

        lower, higher = price.split("~")  
            
        lower_market_price.append(float(lower.strip()[1:-1].strip()) * 1000000 
                                  if lower.strip().endswith("M") 
                                  else float(lower.strip()[1:-1].strip())* 1000)
        higher_market_price.append(float(higher.strip()[:-1].strip()) * 1000000
                                  if higher.strip().endswith("M") 
                                  else float(higher.strip()[1:-1].strip())* 1000)
        
    return lower_market_price, higher_market_price

# %%
# for i in df["market_price"]:
#     print(i)

# %%
# df[["lower_market_price", "lower_market_price"]] = df["market_price"].apply(get_market_price_range)

lower_market_price, higher_market_price = get_market_price_range(df["market_price"])

# %%
len(lower_market_price)
# Out:
# 5122

# %%
len(higher_market_price)
# Out:
# 5122

# %%
# columns for lower_market_price and higher_market_price
df2 = pd.DataFrame(list(zip(lower_market_price, higher_market_price)), columns =["lower_market_price", "higher_market_price"])

# %%
df2
# Out:
#       lower_market_price  higher_market_price
# 0             13480000.0           14500000.0
# 1             17500000.0           18500000.0
# 2              6500000.0            7100000.0
# 3              4800000.0            5240000.0
# 4             13500000.0           13900000.0
# ...                  ...                  ...
# 5117           4700000.0            4800000.0
# 5118           4470000.0            4600000.0
# 5119          17500000.0           18500000.0
# 5120          12440000.0           13060000.0
# 5121           5200000.0            6200000.0
#
# [5122 rows x 2 columns]

# %%
# combine the 2 dataframes
df = pd.concat([df2, df], axis=1)
df
# Out:
#       lower_market_price  higher_market_price  \
# 0             13480000.0           14500000.0
# 1             17500000.0           18500000.0
# 2              6500000.0            7100000.0
# 3              4800000.0            5240000.0
# 4             13500000.0           13900000.0
# ...                  ...                  ...
# 5117           4700000.0            4800000.0
# 5118           4470000.0            4600000.0
# 5119          17500000.0           18500000.0
# 5120          12440000.0           13060000.0
# 5121           5200000.0            6200000.0
#
#                                           name          price  \
# 0                     Toyota Tacoma 2014 White    ₦ 8,800,000
# 1                       Lexus GX 460 2010 Gray   ₦ 19,500,000
# 2                           Acura MDX 2011 Red   ₦ 7,500,000,
# 3           Hyundai Elantra Limited 2012 Black    ₦ 4,800,000
# 4                  Lexus RX 350 AWD 2013 White   ₦ 13,500,000
# ...                                        ...            ...
# 5117                   Ford Explorer 2013 Blue    ₦ 4,200,000
# 5118       Toyota RAV4 2.5 Sport 4x4 2011 Gray   ₦ 4,650,000,
# 5119                   Lexus GX 460 2010 Black   ₦ 10,200,000
# 5120               Lexus ES 350 FWD 2014 Black  ₦ 12,850,000,
# 5121  Toyota Sienna LE 7 Passenger 2011 Silver    ₦ 5,990,000
#
#              market_price             location       gear  odometer fuel_type  \
# 0      ₦ 13.48 M ~ 14.5 M          Lagos, Ajah  Automatic       NaN    Petrol
# 1       ₦ 17.5 M ~ 18.5 M        Lagos, Magodo  Automatic       NaN    Petrol
# 2         ₦ 6.5 M ~ 7.1 M         Lagos, Apapa  Automatic  75000 km    Petrol
# 3        ₦ 4.8 M ~ 5.24 M           Lagos, Ojo  Automatic       NaN    Petrol
# 4       ₦ 13.5 M ~ 13.9 M       Lagos, Gbagada  Automatic  70431 km    Petrol
# ...                   ...                  ...        ...       ...       ...
# 5117      ₦ 4.7 M ~ 4.8 M         Lagos, Agege  Automatic       NaN       NaN
# 5118     ₦ 4.47 M ~ 4.6 M          Lagos, Ajah  Automatic       NaN    Petrol
# 5119    ₦ 17.5 M ~ 18.5 M          Lagos, Ajah  Automatic  80000 km    Petrol
# 5120  ₦ 12.44 M ~ 13.06 M         Lagos, Ikeja  Automatic       NaN    Petrol
# 5121      ₦ 5.2 M ~ 6.2 M  Lagos, Amuwo-Odofin  Automatic       NaN    Petrol
#
#       car_condition  ... number_of_cylinders       horse_power   color seats  \
# 0      Foreign Used  ...                 4.0  159           hp   White   NaN
# 1      Foreign Used  ...                 8.0  305           hp    Gray     7
# 2      Foreign Used  ...                 6.0  300           hp     Red     7
# 3      Foreign Used  ...                 4.0  150           hp   Black     5
# 4      Foreign Used  ...                 6.0  270           hp   White     5
# ...             ...  ...                 ...               ...     ...   ...
# 5117  Nigerian Used  ...                 NaN               NaN    Blue   NaN
# 5118  Nigerian Used  ...                 4.0               NaN    Gray     5
# 5119   Foreign Used  ...                 8.0  305           hp   Black     7
# 5120   Foreign Used  ...                 6.0  268           hp   Black     5
# 5121  Nigerian Used  ...                 6.0  270           hp  Silver     7
#
#      registered_car  exchange_possible vin_chassis_number mileage vin_number  \
# 0               NaN                NaN                NaN     NaN        NaN
# 1               NaN                NaN                NaN     NaN        NaN
# 2                No                NaN                NaN     NaN        NaN
# 3                No                NaN                NaN     NaN        NaN
# 4               NaN                NaN                NaN     NaN        NaN
# ...             ...                ...                ...     ...        ...
# 5117            Yes                NaN                NaN     NaN        NaN
# 5118            NaN                NaN                NaN     NaN        NaN
# 5119             No                NaN                NaN     NaN        NaN
# 5120             No                 No                NaN     NaN        NaN
# 5121            Yes                NaN                NaN     NaN        NaN
#
#      actual_price
# 0       8800000.0
# 1      19500000.0
# 2       7500000.0
# 3       4800000.0
# 4      13500000.0
# ...           ...
# 5117    4200000.0
# 5118    4650000.0
# 5119   10200000.0
# 5120   12850000.0
# 5121    5990000.0
#
# [5122 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['lower_market_price', 'higher_market_price', 'name', 'price',
#        'market_price', 'location', 'gear', 'odometer', 'fuel_type',
#        'car_condition', 'other_features', 'dealer_name', 'second_condition',
#        'make', 'model', 'year_of_manufacture', 'trim', 'body', 'drivetrain',
#        'engine_size', 'number_of_cylinders', 'horse_power', 'color', 'seats',
#        'registered_car', 'exchange_possible', 'vin_chassis_number', 'mileage',
#        'vin_number', 'actual_price'],
#       dtype='object')

# %%
df.head()
# Out:
#    lower_market_price  higher_market_price  \
# 0          13480000.0           14500000.0
# 1          17500000.0           18500000.0
# 2           6500000.0            7100000.0
# 3           4800000.0            5240000.0
# 4          13500000.0           13900000.0
#
#                                  name         price        market_price  \
# 0            Toyota Tacoma 2014 White   ₦ 8,800,000  ₦ 13.48 M ~ 14.5 M
# 1              Lexus GX 460 2010 Gray  ₦ 19,500,000   ₦ 17.5 M ~ 18.5 M
# 2                  Acura MDX 2011 Red  ₦ 7,500,000,     ₦ 6.5 M ~ 7.1 M
# 3  Hyundai Elantra Limited 2012 Black   ₦ 4,800,000    ₦ 4.8 M ~ 5.24 M
# 4         Lexus RX 350 AWD 2013 White  ₦ 13,500,000   ₦ 13.5 M ~ 13.9 M
#
#          location       gear  odometer fuel_type car_condition  ...  \
# 0     Lagos, Ajah  Automatic       NaN    Petrol  Foreign Used  ...
# 1   Lagos, Magodo  Automatic       NaN    Petrol  Foreign Used  ...
# 2    Lagos, Apapa  Automatic  75000 km    Petrol  Foreign Used  ...
# 3      Lagos, Ojo  Automatic       NaN    Petrol  Foreign Used  ...
# 4  Lagos, Gbagada  Automatic  70431 km    Petrol  Foreign Used  ...
#
#   number_of_cylinders       horse_power  color seats registered_car  \
# 0                 4.0  159           hp  White   NaN            NaN
# 1                 8.0  305           hp   Gray     7            NaN
# 2                 6.0  300           hp    Red     7             No
# 3                 4.0  150           hp  Black     5             No
# 4                 6.0  270           hp  White     5            NaN
#
#    exchange_possible vin_chassis_number mileage vin_number actual_price
# 0                NaN                NaN     NaN        NaN    8800000.0
# 1                NaN                NaN     NaN        NaN   19500000.0
# 2                NaN                NaN     NaN        NaN    7500000.0
# 3                NaN                NaN     NaN        NaN    4800000.0
# 4                NaN                NaN     NaN        NaN   13500000.0
#
# [5 rows x 30 columns]

# %%
# print("Lower price: ", lower_market_price, type(lower_market_price))
# print("Higher price: ", higher_market_price, type(higher_market_price))

# %%
df = df[df["year_of_manufacture"].notna()]
df["year_of_manufacture"].isna().sum()
# Out:
# 0

# %%
df["year_of_manufacture"].apply(lambda x: int(x))
df
# Out:
#       lower_market_price  higher_market_price  \
# 0             13480000.0           14500000.0
# 1             17500000.0           18500000.0
# 2              6500000.0            7100000.0
# 3              4800000.0            5240000.0
# 4             13500000.0           13900000.0
# ...                  ...                  ...
# 5117           4700000.0            4800000.0
# 5118           4470000.0            4600000.0
# 5119          17500000.0           18500000.0
# 5120          12440000.0           13060000.0
# 5121           5200000.0            6200000.0
#
#                                           name          price  \
# 0                     Toyota Tacoma 2014 White    ₦ 8,800,000
# 1                       Lexus GX 460 2010 Gray   ₦ 19,500,000
# 2                           Acura MDX 2011 Red   ₦ 7,500,000,
# 3           Hyundai Elantra Limited 2012 Black    ₦ 4,800,000
# 4                  Lexus RX 350 AWD 2013 White   ₦ 13,500,000
# ...                                        ...            ...
# 5117                   Ford Explorer 2013 Blue    ₦ 4,200,000
# 5118       Toyota RAV4 2.5 Sport 4x4 2011 Gray   ₦ 4,650,000,
# 5119                   Lexus GX 460 2010 Black   ₦ 10,200,000
# 5120               Lexus ES 350 FWD 2014 Black  ₦ 12,850,000,
# 5121  Toyota Sienna LE 7 Passenger 2011 Silver    ₦ 5,990,000
#
#              market_price             location       gear  odometer fuel_type  \
# 0      ₦ 13.48 M ~ 14.5 M          Lagos, Ajah  Automatic       NaN    Petrol
# 1       ₦ 17.5 M ~ 18.5 M        Lagos, Magodo  Automatic       NaN    Petrol
# 2         ₦ 6.5 M ~ 7.1 M         Lagos, Apapa  Automatic  75000 km    Petrol
# 3        ₦ 4.8 M ~ 5.24 M           Lagos, Ojo  Automatic       NaN    Petrol
# 4       ₦ 13.5 M ~ 13.9 M       Lagos, Gbagada  Automatic  70431 km    Petrol
# ...                   ...                  ...        ...       ...       ...
# 5117      ₦ 4.7 M ~ 4.8 M         Lagos, Agege  Automatic       NaN       NaN
# 5118     ₦ 4.47 M ~ 4.6 M          Lagos, Ajah  Automatic       NaN    Petrol
# 5119    ₦ 17.5 M ~ 18.5 M          Lagos, Ajah  Automatic  80000 km    Petrol
# 5120  ₦ 12.44 M ~ 13.06 M         Lagos, Ikeja  Automatic       NaN    Petrol
# 5121      ₦ 5.2 M ~ 6.2 M  Lagos, Amuwo-Odofin  Automatic       NaN    Petrol
#
#       car_condition  ... number_of_cylinders       horse_power   color seats  \
# 0      Foreign Used  ...                 4.0  159           hp   White   NaN
# 1      Foreign Used  ...                 8.0  305           hp    Gray     7
# 2      Foreign Used  ...                 6.0  300           hp     Red     7
# 3      Foreign Used  ...                 4.0  150           hp   Black     5
# 4      Foreign Used  ...                 6.0  270           hp   White     5
# ...             ...  ...                 ...               ...     ...   ...
# 5117  Nigerian Used  ...                 NaN               NaN    Blue   NaN
# 5118  Nigerian Used  ...                 4.0               NaN    Gray     5
# 5119   Foreign Used  ...                 8.0  305           hp   Black     7
# 5120   Foreign Used  ...                 6.0  268           hp   Black     5
# 5121  Nigerian Used  ...                 6.0  270           hp  Silver     7
#
#      registered_car  exchange_possible vin_chassis_number mileage vin_number  \
# 0               NaN                NaN                NaN     NaN        NaN
# 1               NaN                NaN                NaN     NaN        NaN
# 2                No                NaN                NaN     NaN        NaN
# 3                No                NaN                NaN     NaN        NaN
# 4               NaN                NaN                NaN     NaN        NaN
# ...             ...                ...                ...     ...        ...
# 5117            Yes                NaN                NaN     NaN        NaN
# 5118            NaN                NaN                NaN     NaN        NaN
# 5119             No                NaN                NaN     NaN        NaN
# 5120             No                 No                NaN     NaN        NaN
# 5121            Yes                NaN                NaN     NaN        NaN
#
#      actual_price
# 0       8800000.0
# 1      19500000.0
# 2       7500000.0
# 3       4800000.0
# 4      13500000.0
# ...           ...
# 5117    4200000.0
# 5118    4650000.0
# 5119   10200000.0
# 5120   12850000.0
# 5121    5990000.0
#
# [5097 rows x 30 columns]

# %%
df["present_year"] = 2023
df["years_old"] = df["present_year"] - df["year_of_manufacture"]
df
# Out:
# /tmp/ipykernel_7143/1976145359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["present_year"] = 2023
# /tmp/ipykernel_7143/1976145359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["years_old"] = df["present_year"] - df["year_of_manufacture"]
#       lower_market_price  higher_market_price  \
# 0             13480000.0           14500000.0
# 1             17500000.0           18500000.0
# 2              6500000.0            7100000.0
# 3              4800000.0            5240000.0
# 4             13500000.0           13900000.0
# ...                  ...                  ...
# 5117           4700000.0            4800000.0
# 5118           4470000.0            4600000.0
# 5119          17500000.0           18500000.0
# 5120          12440000.0           13060000.0
# 5121           5200000.0            6200000.0
#
#                                           name          price  \
# 0                     Toyota Tacoma 2014 White    ₦ 8,800,000
# 1                       Lexus GX 460 2010 Gray   ₦ 19,500,000
# 2                           Acura MDX 2011 Red   ₦ 7,500,000,
# 3           Hyundai Elantra Limited 2012 Black    ₦ 4,800,000
# 4                  Lexus RX 350 AWD 2013 White   ₦ 13,500,000
# ...                                        ...            ...
# 5117                   Ford Explorer 2013 Blue    ₦ 4,200,000
# 5118       Toyota RAV4 2.5 Sport 4x4 2011 Gray   ₦ 4,650,000,
# 5119                   Lexus GX 460 2010 Black   ₦ 10,200,000
# 5120               Lexus ES 350 FWD 2014 Black  ₦ 12,850,000,
# 5121  Toyota Sienna LE 7 Passenger 2011 Silver    ₦ 5,990,000
#
#              market_price             location       gear  odometer fuel_type  \
# 0      ₦ 13.48 M ~ 14.5 M          Lagos, Ajah  Automatic       NaN    Petrol
# 1       ₦ 17.5 M ~ 18.5 M        Lagos, Magodo  Automatic       NaN    Petrol
# 2         ₦ 6.5 M ~ 7.1 M         Lagos, Apapa  Automatic  75000 km    Petrol
# 3        ₦ 4.8 M ~ 5.24 M           Lagos, Ojo  Automatic       NaN    Petrol
# 4       ₦ 13.5 M ~ 13.9 M       Lagos, Gbagada  Automatic  70431 km    Petrol
# ...                   ...                  ...        ...       ...       ...
# 5117      ₦ 4.7 M ~ 4.8 M         Lagos, Agege  Automatic       NaN       NaN
# 5118     ₦ 4.47 M ~ 4.6 M          Lagos, Ajah  Automatic       NaN    Petrol
# 5119    ₦ 17.5 M ~ 18.5 M          Lagos, Ajah  Automatic  80000 km    Petrol
# 5120  ₦ 12.44 M ~ 13.06 M         Lagos, Ikeja  Automatic       NaN    Petrol
# 5121      ₦ 5.2 M ~ 6.2 M  Lagos, Amuwo-Odofin  Automatic       NaN    Petrol
#
#       car_condition  ...   color seats registered_car exchange_possible  \
# 0      Foreign Used  ...   White   NaN            NaN               NaN
# 1      Foreign Used  ...    Gray     7            NaN               NaN
# 2      Foreign Used  ...     Red     7             No               NaN
# 3      Foreign Used  ...   Black     5             No               NaN
# 4      Foreign Used  ...   White     5            NaN               NaN
# ...             ...  ...     ...   ...            ...               ...
# 5117  Nigerian Used  ...    Blue   NaN            Yes               NaN
# 5118  Nigerian Used  ...    Gray     5            NaN               NaN
# 5119   Foreign Used  ...   Black     7             No               NaN
# 5120   Foreign Used  ...   Black     5             No                No
# 5121  Nigerian Used  ...  Silver     7            Yes               NaN
#
#      vin_chassis_number  mileage vin_number actual_price present_year  \
# 0                   NaN      NaN        NaN    8800000.0         2023
# 1                   NaN      NaN        NaN   19500000.0         2023
# 2                   NaN      NaN        NaN    7500000.0         2023
# 3                   NaN      NaN        NaN    4800000.0         2023
# 4                   NaN      NaN        NaN   13500000.0         2023
# ...                 ...      ...        ...          ...          ...
# 5117                NaN      NaN        NaN    4200000.0         2023
# 5118                NaN      NaN        NaN    4650000.0         2023
# 5119                NaN      NaN        NaN   10200000.0         2023
# 5120                NaN      NaN        NaN   12850000.0         2023
# 5121                NaN      NaN        NaN    5990000.0         2023
#
#      years_old
# 0          9.0
# 1         13.0
# 2         12.0
# 3         11.0
# 4         10.0
# ...        ...
# 5117      10.0
# 5118      12.0
# 5119      13.0
# 5120       9.0
# 5121      12.0
#
# [5097 rows x 32 columns]

# %%
df["fuel_type"] = df["fuel_type"].fillna(df["fuel_type"].mode()[0])
df.head()
# Out:
# /tmp/ipykernel_7143/2599570982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fuel_type"] = df["fuel_type"].fillna(df["fuel_type"].mode()[0])
#    lower_market_price  higher_market_price  \
# 0          13480000.0           14500000.0
# 1          17500000.0           18500000.0
# 2           6500000.0            7100000.0
# 3           4800000.0            5240000.0
# 4          13500000.0           13900000.0
#
#                                  name         price        market_price  \
# 0            Toyota Tacoma 2014 White   ₦ 8,800,000  ₦ 13.48 M ~ 14.5 M
# 1              Lexus GX 460 2010 Gray  ₦ 19,500,000   ₦ 17.5 M ~ 18.5 M
# 2                  Acura MDX 2011 Red  ₦ 7,500,000,     ₦ 6.5 M ~ 7.1 M
# 3  Hyundai Elantra Limited 2012 Black   ₦ 4,800,000    ₦ 4.8 M ~ 5.24 M
# 4         Lexus RX 350 AWD 2013 White  ₦ 13,500,000   ₦ 13.5 M ~ 13.9 M
#
#          location       gear  odometer fuel_type car_condition  ...  color  \
# 0     Lagos, Ajah  Automatic       NaN    Petrol  Foreign Used  ...  White
# 1   Lagos, Magodo  Automatic       NaN    Petrol  Foreign Used  ...   Gray
# 2    Lagos, Apapa  Automatic  75000 km    Petrol  Foreign Used  ...    Red
# 3      Lagos, Ojo  Automatic       NaN    Petrol  Foreign Used  ...  Black
# 4  Lagos, Gbagada  Automatic  70431 km    Petrol  Foreign Used  ...  White
#
#   seats registered_car exchange_possible vin_chassis_number  mileage  \
# 0   NaN            NaN               NaN                NaN      NaN
# 1     7            NaN               NaN                NaN      NaN
# 2     7             No               NaN                NaN      NaN
# 3     5             No               NaN                NaN      NaN
# 4     5            NaN               NaN                NaN      NaN
#
#   vin_number actual_price present_year years_old
# 0        NaN    8800000.0         2023       9.0
# 1        NaN   19500000.0         2023      13.0
# 2        NaN    7500000.0         2023      12.0
# 3        NaN    4800000.0         2023      11.0
# 4        NaN   13500000.0         2023      10.0
#
# [5 rows x 32 columns]

# %%
selection = ["gear", "odometer", "fuel_type", "car_condition", "second_condition", "engine_size", "horse_power", "years_old", "lower_market_price", "higher_market_price", "actual_price"]
df = df[selection]

# %%
df.head()
# Out:
#         gear  odometer fuel_type car_condition           second_condition  \
# 0  Automatic       NaN    Petrol  Foreign Used                  No faults
# 1  Automatic       NaN    Petrol  Foreign Used  No faults, Original parts
# 2  Automatic  75000 km    Petrol  Foreign Used                  No faults
# 3  Automatic       NaN    Petrol  Foreign Used                  No faults
# 4  Automatic  70431 km    Petrol  Foreign Used                  No faults
#
#          engine_size       horse_power  years_old  lower_market_price  \
# 0  2700           cc  159           hp        9.0          13480000.0
# 1  4600           cc  305           hp       13.0          17500000.0
# 2  3700           cc  300           hp       12.0           6500000.0
# 3  1800           cc  150           hp       11.0           4800000.0
# 4  3500           cc  270           hp       10.0          13500000.0
#
#    higher_market_price  actual_price
# 0           14500000.0     8800000.0
# 1           18500000.0    19500000.0
# 2            7100000.0     7500000.0
# 3            5240000.0     4800000.0
# 4           13900000.0    13500000.0

# %%
def extract_value(column):
    value = int(column.split()[0].strip()) if isinstance(column, str) else np.nan
    return value

# %%
df["horse_power"] = df["horse_power"].apply(extract_value)
df["engine_size"] = df["engine_size"].apply(extract_value)
df["odometer"] = df["odometer"].apply(extract_value)
# Out:
# /tmp/ipykernel_7143/3681308768.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["horse_power"] = df["horse_power"].apply(extract_value)
# /tmp/ipykernel_7143/3681308768.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["engine_size"] = df["engine_size"].apply(extract_value)
# /tmp/ipykernel_7143/3681308768.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["odometer"] = df["odometer"].apply(extract_value)

# %%
df.head()
# Out:
#         gear  odometer fuel_type car_condition           second_condition  \
# 0  Automatic       NaN    Petrol  Foreign Used                  No faults
# 1  Automatic       NaN    Petrol  Foreign Used  No faults, Original parts
# 2  Automatic   75000.0    Petrol  Foreign Used                  No faults
# 3  Automatic       NaN    Petrol  Foreign Used                  No faults
# 4  Automatic   70431.0    Petrol  Foreign Used                  No faults
#
#    engine_size  horse_power  years_old  lower_market_price  \
# 0       2700.0        159.0        9.0          13480000.0
# 1       4600.0        305.0       13.0          17500000.0
# 2       3700.0        300.0       12.0           6500000.0
# 3       1800.0        150.0       11.0           4800000.0
# 4       3500.0        270.0       10.0          13500000.0
#
#    higher_market_price  actual_price
# 0           14500000.0     8800000.0
# 1           18500000.0    19500000.0
# 2            7100000.0     7500000.0
# 3            5240000.0     4800000.0
# 4           13900000.0    13500000.0

# %%
for column in df.columns:
    print(column, df[column].isna().sum())
# Out:
# gear 0
# odometer 2598
# fuel_type 0
# car_condition 0
# second_condition 3
# engine_size 2201
# horse_power 2335
# years_old 0
# lower_market_price 774
# higher_market_price 774
# actual_price 0

# %%
#clean engine_size and horse_power columns

def fill_nan(column):
    df[column] = df[column].fillna(round(df[column].mean()))
    return df[column]

df["engine_size"] = fill_nan("engine_size")
df["horse_power"] = fill_nan("horse_power")
df["lower_market_price"] = fill_nan("lower_market_price")
df["higher_market_price"] = fill_nan("higher_market_price")
# Out:
# /tmp/ipykernel_7143/52763993.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].fillna(round(df[column].mean()))
# /tmp/ipykernel_7143/52763993.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["engine_size"] = fill_nan("engine_size")
# /tmp/ipykernel_7143/52763993.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["horse_power"] = fill_nan("horse_power")
# /tmp/ipykernel_7143/52763993.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["lower_market_price"] = fill_nan("lower_market_price")
# /tmp/ipykernel_7143/52763993.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["higher_market_price"] = fill_nan("higher_market_price")

# %%
df = df.drop("odometer", axis=1)
df.head()
# Out:
#         gear fuel_type car_condition           second_condition  engine_size  \
# 0  Automatic    Petrol  Foreign Used                  No faults       2700.0
# 1  Automatic    Petrol  Foreign Used  No faults, Original parts       4600.0
# 2  Automatic    Petrol  Foreign Used                  No faults       3700.0
# 3  Automatic    Petrol  Foreign Used                  No faults       1800.0
# 4  Automatic    Petrol  Foreign Used                  No faults       3500.0
#
#    horse_power  years_old  lower_market_price  higher_market_price  \
# 0        159.0        9.0          13480000.0           14500000.0
# 1        305.0       13.0          17500000.0           18500000.0
# 2        300.0       12.0           6500000.0            7100000.0
# 3        150.0       11.0           4800000.0            5240000.0
# 4        270.0       10.0          13500000.0           13900000.0
#
#    actual_price
# 0     8800000.0
# 1    19500000.0
# 2     7500000.0
# 3     4800000.0
# 4    13500000.0

# %%
df["second_condition"] = df["second_condition"].fillna(df["second_condition"].mode())

# %%
df["second_condition"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 5097 entries, 0 to 5121
# Series name: second_condition
# Non-Null Count  Dtype
# --------------  -----
# 5094 non-null   object
# dtypes: object(1)
# memory usage: 79.6+ KB

# %%
df
# Out:
#            gear fuel_type  car_condition           second_condition  \
# 0     Automatic    Petrol   Foreign Used                  No faults
# 1     Automatic    Petrol   Foreign Used  No faults, Original parts
# 2     Automatic    Petrol   Foreign Used                  No faults
# 3     Automatic    Petrol   Foreign Used                  No faults
# 4     Automatic    Petrol   Foreign Used                  No faults
# ...         ...       ...            ...                        ...
# 5117  Automatic    Petrol  Nigerian Used                  No faults
# 5118  Automatic    Petrol  Nigerian Used                  No faults
# 5119  Automatic    Petrol   Foreign Used                  No faults
# 5120  Automatic    Petrol   Foreign Used                  No faults
# 5121  Automatic    Petrol  Nigerian Used                  No faults
#
#       engine_size  horse_power  years_old  lower_market_price  \
# 0          2700.0        159.0        9.0          13480000.0
# 1          4600.0        305.0       13.0          17500000.0
# 2          3700.0        300.0       12.0           6500000.0
# 3          1800.0        150.0       11.0           4800000.0
# 4          3500.0        270.0       10.0          13500000.0
# ...           ...          ...        ...                 ...
# 5117       3287.0        246.0       10.0           4700000.0
# 5118       2500.0        246.0       12.0           4470000.0
# 5119       4600.0        305.0       13.0          17500000.0
# 5120       3500.0        268.0        9.0          12440000.0
# 5121       3500.0        270.0       12.0           5200000.0
#
#       higher_market_price  actual_price
# 0              14500000.0     8800000.0
# 1              18500000.0    19500000.0
# 2               7100000.0     7500000.0
# 3               5240000.0     4800000.0
# 4              13900000.0    13500000.0
# ...                   ...           ...
# 5117            4800000.0     4200000.0
# 5118            4600000.0     4650000.0
# 5119           18500000.0    10200000.0
# 5120           13060000.0    12850000.0
# 5121            6200000.0     5990000.0
#
# [5097 rows x 10 columns]

# %%
df["second_condition"].unique()
# Out:
# array(['No faults', 'No faults, Original parts',
#        'Unpainted, Original parts, No faults', 'Unpainted',
#        'No faults, Unpainted, Original parts', 'Original parts',
#        'First owner, No faults, Unpainted',
#        'Need repainting, Need body repair', 'Unpainted, No faults',
#        'No faults, Unpainted', 'No faults, Original parts, Unpainted',
#        'Engine issue, No faults, First owner',
#        'Original parts, No faults, Unpainted',
#        'Original parts, Unpainted, No faults',
#        'Gear issue, Need repair, Unpainted', 'Engine issue',
#        'No faults, Original parts, First owner',
#        'First owner, First registration, No faults', 'First owner',
#        'No faults, First registration, First owner',
#        'First registration, Original parts',
#        'Unpainted, First registration, Original parts',
#        'No faults, First owner',
#        'First registration, First owner, Unpainted',
#        'Original parts, First registration, First owner',
#        'No faults, First owner, First registration',
#        'First owner, First registration',
#        'Unpainted, No faults, Original parts',
#        'Original parts, No faults',
#        'First registration, No faults, Original parts',
#        'First registration, First owner, No faults',
#        'No faults, First registration, Original parts',
#        'First registration, No faults', 'Original parts, Unpainted',
#        'Wiring problems', 'No faults, First owner, Original parts',
#        'No faults, Original parts, First registration',
#        'Original parts, No faults, First registration',
#        'First registration', 'First owner, First registration, Unpainted',
#        'No faults, Unpainted, First registration',
#        'Gear issue, Need body repair',
#        'First owner, No faults, First registration',
#        'Unpainted, Original parts',
#        'First owner, Original parts, Unpainted',
#        'No faults, First registration', 'Need repainting',
#        'Need body repair', 'First owner, Original parts, No faults',
#        'Wiring problems, No faults, Unpainted',
#        'Original parts, First owner, Unpainted',
#        'First registration, No faults, First owner',
#        'First owner, No faults', 'First owner, No faults, Original parts',
#        'Unpainted, First owner, First registration',
#        'No faults, Original parts, Wiring problems',
#        'No faults, First owner, Unpainted',
#        'First owner, Unpainted, Original parts', 'After crash, No faults',
#        'First registration, First owner, Original parts',
#        'Unpainted, First owner, No faults', 'No faults, Need body repair',
#        'First registration, No faults, Unpainted',
#        'Original parts, No faults, First owner',
#        'First owner, First registration, Original parts',
#        'Need repainting, Original parts',
#        'First registration, Unpainted, No faults',
#        'Unpainted, No faults, First owner', 'Need repainting, No faults',
#        'Original parts, First registration, No faults',
#        'No faults, First registration, Unpainted',
#        'First registration, First owner',
#        'Original parts, First owner, First registration',
#        'Unpainted, No faults, First registration', nan,
#        'First owner, Original parts',
#        'First registration, Original parts, Unpainted',
#        'Original parts, First registration, Unpainted',
#        'Original parts, Unpainted, First owner',
#        'No faults, Original parts, After crash', 'Need repair, Unpainted',
#        'First registration, Original parts, No faults', 'Need repair',
#        'No faults, Need repainting',
#        'First registration, Unpainted, First owner', 'Gear issue',
#        'Unpainted, Original parts, First owner', 'First owner, Unpainted',
#        'First owner, Unpainted, First registration',
#        'No faults, Wiring problems, Original parts',
#        'No faults, Original parts, Need repair',
#        'No faults, Unpainted, First owner',
#        'First owner, Need repainting, First registration',
#        'No faults, After crash', 'Original parts, First registration',
#        'Unpainted, First owner, Original parts', 'After crash',
#        'Need repair, Original parts', 'No faults, Wiring problems',
#        'Original parts, First owner'], dtype=object)

# %%
df["second_condition"].isna().sum()
# Out:
# 3

# %%
df["second_condition"] = df["second_condition"].fillna(df["second_condition"].mode()[0])

# %%
df["second_condition"].isna().sum()
# Out:
# 0

# %%
df["second_condition"].mode()[0]
# Out:
# 'No faults'

# %% [markdown]
# **cleaning the second condition column**

# %%
conditions = []

for condition in df["second_condition"].unique():
    # nan values has been droped.. But let's handle it in case..
    if not isinstance(condition, str):
        conditions.append(np.nan)
        continue
    for value in condition.split(","):
        value = value.strip()
        if value not in conditions:
            conditions.append(value)

# %%
conditions
# Out:
# ['No faults',
#  'Original parts',
#  'Unpainted',
#  'First owner',
#  'Need repainting',
#  'Need body repair',
#  'Engine issue',
#  'Gear issue',
#  'Need repair',
#  'First registration',
#  'Wiring problems',
#  'After crash']

# %%
new_condition_column = []

for condition in df["second_condition"]:
    a = [x.strip() for x in condition.split(",")]
    new_condition_column.append(",".join(a))

# %%
df["second_condition"] = pd.Series(new_condition_column)

# %%
# generate new column from second_condition column
second_condition_columns = [condition.replace(" ", "_").lower() for condition in conditions]

# %%
# second_condition_columns

# %%
d = {}

# for i in df["second_condition"]:
#     aa = ["yes" for i.split(",")
#     for a in conditions:
#         print(a)

for x in second_condition_columns:
    d[x] = []

# %%
d
# Out:
# {'no_faults': [],
#  'original_parts': [],
#  'unpainted': [],
#  'first_owner': [],
#  'need_repainting': [],
#  'need_body_repair': [],
#  'engine_issue': [],
#  'gear_issue': [],
#  'need_repair': [],
#  'first_registration': [],
#  'wiring_problems': [],
#  'after_crash': []}

# %%
# for column in df["second_condition"].unique():
#     {}

# %%
# def add_other_features_column(other_feature_column):
    
#     conditions = []
#     df_dict = {}

#     for condition in df["second_condition"].unique():
#         # nan values has been droped.. But let's handle it in case..
#         if not isinstance(condition, str):
#             conditions.append(np.nan)
#             continue
#         for value in condition.split(","):
#             value = value.strip()
#             if value not in conditions:
#                 conditions.append(value)
                
#     # convert the column's name to snake case
#     columns = [condition.replace(" ", "_").lower() for condition in conditions]
    
#     return columns

# %%
# add_other_features_column(df["second_condition"])

# %%
# for condition in conditions:
#     for column in df["second_condition"].unique():
#         for values in [x.strip() for x in column.split(",")]:
# #             print(condition)
#             if condition in values:
#                 print("Yes")
#             else:
#                 print("No")
# #                 new_column = column.replace(" ", "_").lower()



# df2 = pd.DataFrame()

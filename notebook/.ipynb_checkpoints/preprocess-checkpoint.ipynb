# %% [markdown]
# ## Car price prediction

# %% [markdown]
# ### Data Preprocessing
# #### Features selection

# %% [markdown]
# *Import required libraries and packages*

# %%
# required libraries and pakages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# *Load dataset*

# %%
# Load the dataset
df = pd.read_csv('../dataset/new_scrape.csv')

# %%
# take a look of the data
print("Shape: ", df.shape)
df.head(12)
# Out:
# Shape:  (5122, 30)
#                                       Name         Price        Market price  \
# 0                 Toyota Tacoma 2014 White   ₦ 8,800,000  ₦ 13.48 M ~ 14.5 M
# 1                   Lexus GX 460 2010 Gray  ₦ 19,500,000   ₦ 17.5 M ~ 18.5 M
# 2                       Acura MDX 2011 Red  ₦ 7,500,000,     ₦ 6.5 M ~ 7.1 M
# 3       Hyundai Elantra Limited 2012 Black   ₦ 4,800,000    ₦ 4.8 M ~ 5.24 M
# 4              Lexus RX 350 AWD 2013 White  ₦ 13,500,000   ₦ 13.5 M ~ 13.9 M
# 5   Toyota Tacoma 4x4 Access Cab 2008 Gray   ₦ 8,750,000   ₦ 8.52 M ~ 8.74 M
# 6            Toyota Highlander 2005 Silver  ₦ 6,100,000,     ₦ 5.5 M ~ 5.6 M
# 7      Toyota Highlander Limited 2012 Gray  ₦ 11,500,000     ₦ 11 M ~ 11.7 M
# 8       Pontiac Vibe Automatic 2004 Silver   ₦ 3,350,000   ₦ 3.22 M ~ 3.34 M
# 9               Lexus RX 330 4WD 2005 Gray  ₦ 6,000,000,    ₦ 6.39 M ~ 6.5 M
# 10     Mercedes-Benz GLC-Class 2016 Silver  ₦ 26,000,000                 NaN
# 11                   Toyota RAV4 2013 Gray  ₦ 10,500,000     ₦ 9.96 M ~ 11 M
#
#            Location                                          Thumbnail  \
# 0       Lagos, Ajah  https://pictures-nigeria.jijistatic.com/112155...
# 1     Lagos, Magodo  https://pictures-nigeria.jijistatic.com/113346...
# 2      Lagos, Apapa  https://pictures-nigeria.jijistatic.com/107470...
# 3        Lagos, Ojo  https://pictures-nigeria.jijistatic.com/912612...
# 4    Lagos, Gbagada  https://pictures-nigeria.jijistatic.com/111479...
# 5   Abuja, Gwarinpa  https://pictures-nigeria.jijistatic.com/115727...
# 6      Lagos, Agege  https://pictures-nigeria.jijistatic.com/116686...
# 7     Lagos, Magodo  https://pictures-nigeria.jijistatic.com/113202...
# 8     Lagos, Magodo  https://pictures-nigeria.jijistatic.com/116154...
# 9      Lagos, Ojodu  https://pictures-nigeria.jijistatic.com/101762...
# 10      Lagos, Ajah  https://pictures-nigeria.jijistatic.com/115164...
# 11     Lagos, Ojota  https://pictures-nigeria.jijistatic.com/111023...
#
#                                                Images       Gear   Odometer  \
# 0   https://pictures-nigeria.jijistatic.com/112155...  Automatic        NaN
# 1   https://pictures-nigeria.jijistatic.com/113346...  Automatic        NaN
# 2   https://pictures-nigeria.jijistatic.com/107470...  Automatic   75000 km
# 3   https://pictures-nigeria.jijistatic.com/912612...  Automatic        NaN
# 4   https://pictures-nigeria.jijistatic.com/111479...  Automatic   70431 km
# 5   https://pictures-nigeria.jijistatic.com/115727...  Automatic   98052 km
# 6   https://pictures-nigeria.jijistatic.com/116686...  Automatic        NaN
# 7   https://pictures-nigeria.jijistatic.com/113202...  Automatic  100000 km
# 8   https://pictures-nigeria.jijistatic.com/116154...  Automatic  132000 km
# 9   https://pictures-nigeria.jijistatic.com/101762...  Automatic   98000 km
# 10  https://pictures-nigeria.jijistatic.com/115164...        AMT   58847 km
# 11  https://pictures-nigeria.jijistatic.com/111023...  Automatic        NaN
#
#    Fuel type Car condition  ...        Engine Size Number of Cylinders  \
# 0     Petrol  Foreign Used  ...  2700           cc                 4.0
# 1     Petrol  Foreign Used  ...  4600           cc                 8.0
# 2     Petrol  Foreign Used  ...  3700           cc                 6.0
# 3     Petrol  Foreign Used  ...  1800           cc                 4.0
# 4     Petrol  Foreign Used  ...  3500           cc                 6.0
# 5        NaN  Foreign Used  ...  2700           cc                 4.0
# 6        NaN  Foreign Used  ...                NaN                 NaN
# 7     Petrol  Foreign Used  ...  3500           cc                 6.0
# 8     Petrol  Foreign Used  ...  1800           cc                 4.0
# 9     Petrol  Foreign Used  ...  3300           cc                 6.0
# 10       NaN  Foreign Used  ...  2000           cc                 4.0
# 11       NaN  Foreign Used  ...                NaN                 NaN
#
#          Horse Power   Color Seats Registered Car  Exchange Possible  \
# 0   159           hp   White   NaN            NaN                NaN
# 1   305           hp    Gray     7            NaN                NaN
# 2   300           hp     Red     7             No                NaN
# 3   150           hp   Black     5             No                NaN
# 4   270           hp   White     5            NaN                NaN
# 5   161           hp    Gray     4            NaN                NaN
# 6                NaN  Silver   NaN             No                NaN
# 7   274           hp    Gray     5             No                NaN
# 8   124           hp  Silver     5             No                 No
# 9   233           hp    Gray     5             No                NaN
# 10               NaN  Silver   NaN             No                NaN
# 11               NaN    Gray   NaN             No                NaN
#
#    VIN Chassis number Mileage VIN number
# 0                 NaN     NaN        NaN
# 1                 NaN     NaN        NaN
# 2                 NaN     NaN        NaN
# 3                 NaN     NaN        NaN
# 4                 NaN     NaN        NaN
# 5                 NaN     NaN        NaN
# 6                 NaN     NaN        NaN
# 7                 NaN     NaN        NaN
# 8                 NaN     NaN        NaN
# 9                 NaN     NaN        NaN
# 10                NaN     NaN        NaN
# 11                NaN     NaN        NaN
#
# [12 rows x 30 columns]

# %% [markdown]
# ### Column name cleaning

# %%
# Clean dataset column name
df.columns = [column.lower().replace(" ", "_") for column in df.columns]

# %% [markdown]
# ### Since, all the media data and the links are not applicable here, we remove them
# *There is no need for the car images, thumbnail and page link. So, let's drop them.*

# %%
df = df.drop(["thumbnail", "images", "page_link"], axis=1)

# %% [markdown]
# ### Cleaning the *price* column to extract the price digit.

# %%
# custom function to clean up the price column
def clean_price(price):
    new_price = ''.join(price.split()[1].split(','))
    return float(new_price)

# %%
# plt.figure(figsize=(8, 4))
df['price'] = df['price'].apply(clean_price)

# %%
df.columns
# Out:
# Index(['name', 'price', 'market_price', 'location', 'gear', 'odometer',
#        'fuel_type', 'car_condition', 'other_features', 'dealer_name',
#        'second_condition', 'make', 'model', 'year_of_manufacture', 'trim',
#        'body', 'drivetrain', 'engine_size', 'number_of_cylinders',
#        'horse_power', 'color', 'seats', 'registered_car', 'exchange_possible',
#        'vin_chassis_number', 'mileage', 'vin_number'],
#       dtype='object')

# %%
location_count = df.groupby('location')['price'].count().sort_values()

# %%
plt.figure(figsize=(15, 3), dpi=100)
sns.barplot(x=location_count.index, y=location_count)
plt.xticks(rotation=90);

# %%
def get_market_price_range(market_price: str, index) -> tuple:
#     print("Market Price: ", market_price, type(market_price))

    if isinstance(market_price, str):
        
        if "₦" in market_price:
            market_price = market_price.replace("₦", "").split("~")
            
#         print(market_price)
            
        for index, price in enumerate(market_price):
            price = price.strip()
            if "K" in price:
                price = price.replace("K", "").strip()
                market_price[index] = float(price) * 1000
            elif "M" in price:
                price = price.replace("M", "").strip()
                market_price[index] = float(price) * 1000000
                
                
        return market_price[index]

    return market_price

# %%
df["lower_market_price"] = df["market_price"].apply(get_market_price_range)

# %%
df.columns
# Out:
# Index([                                       'name',
#                                              'price',
#                                       'market_price',
#                                           'location',
#                                               'gear',
#                                           'odometer',
#                                          'fuel_type',
#                                      'car_condition',
#                                     'other_features',
#                                        'dealer_name',
#                                   'second_condition',
#                                               'make',
#                                              'model',
#                                'year_of_manufacture',
#                                               'trim',
#                                               'body',
#                                         'drivetrain',
#                                        'engine_size',
#                                'number_of_cylinders',
#                                        'horse_power',
#                                              'color',
#                                              'seats',
#                                     'registered_car',
#                                  'exchange_possible',
#                                 'vin_chassis_number',
#                                            'mileage',
#                                         'vin_number',
#        ('lower_market_price', 'higher_market_price'),
#                                 'lower_market_price'],
#       dtype='object')

# %%
print("Lower price: ", lower_market_price, type(lower_market_price))
print("Higher price: ", higher_market_price, type(higher_market_price))
